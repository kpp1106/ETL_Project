# %% [markdown]
# # ETL Project:
# Stock Market Finances - Currency Exchange Rates

# %%
import os
from config import api_key  
import requests
import pandas as pd
from pprint import pprint
from pandas.io.json import json_normalize
import json

# %% [markdown]
# # URL for GET requests to retrieve currency convert data

# %%
url = "https://api.getgeoapi.com/api/v2/currency/convert?api_key=009b147444557245765ee2f8a2121dc411c0cca0"
#response_json = response.json()
#print(type(response_json))
#print(json.dumps(response_json, indent=4))
response = requests.get(url)
response.json()
# Out:
# {'amount': '1.0000',
#  'base_currency_code': 'EUR',
#  'base_currency_name': 'Euro',
#  'rates': {'AED': {'currency_name': 'UAE Dirham',
#    'rate': '4.3469',
#    'rate_for_amount': '4.3469'},
#   'AFN': {'currency_name': 'Afghani',
#    'rate': '91.3730',
#    'rate_for_amount': '91.3730'},
#   'ALL': {'currency_name': 'Lek',
#    'rate': '124.1247',
#    'rate_for_amount': '124.1247'},
#   'AMD': {'currency_name': 'Armenian Dram',
#    'rate': '584.5809',
#    'rate_for_amount': '584.5809'},
#   'ANG': {'currency_name': 'Netherlands Antillean Guilder',
#    'rate': '2.1156',
#    'rate_for_amount': '2.1156'},
#   'AOA': {'currency_name': 'Kwanza',
#    'rate': '778.4514',
#    'rate_for_amount': '778.4514'},
#   'ARS': {'currency_name': 'Argentine Peso',
#    'rate': '92.3741',
#    'rate_for_amount': '92.3741'},
#   'AUD': {'currency_name': 'Australian Dollar',
#    'rate': '1.6567',
#    'rate_for_amount': '1.6567'},
#   'AWG': {'currency_name': 'Aruban Florin',
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['amount', 'base_currency_code', 'base_currency_name', 'rates', 'status', 'updated_date'])

# %%
# df = pd.json_normalize(response, 'currencies')
# df.head()
df = pd.DataFrame(response.json())
df.head(160)
# df = json_normalize(response.json())
# df.head()
# Out:
#      amount base_currency_code base_currency_name  \
# AED  1.0000                EUR               Euro
# AFN  1.0000                EUR               Euro
# ALL  1.0000                EUR               Euro
# AMD  1.0000                EUR               Euro
# ANG  1.0000                EUR               Euro
# ..      ...                ...                ...
# XAU  1.0000                EUR               Euro
# XCD  1.0000                EUR               Euro
# XDR  1.0000                EUR               Euro
# XOF  1.0000                EUR               Euro
# XPF  1.0000                EUR               Euro
#
#                                                  rates   status updated_date
# AED  {'currency_name': 'UAE Dirham', 'rate': '4.346...  success   2020-10-27
# AFN  {'currency_name': 'Afghani', 'rate': '91.3730'...  success   2020-10-27
# ALL  {'currency_name': 'Lek', 'rate': '124.1247', '...  success   2020-10-27
# ...

# %%
df = df.drop(['status', 'updated_date'], axis=1)

df.head(160)
# Out:
#      amount base_currency_code base_currency_name  \
# AED  1.0000                EUR               Euro
# AFN  1.0000                EUR               Euro
# ALL  1.0000                EUR               Euro
# AMD  1.0000                EUR               Euro
# ANG  1.0000                EUR               Euro
# ..      ...                ...                ...
# XAU  1.0000                EUR               Euro
# XCD  1.0000                EUR               Euro
# XDR  1.0000                EUR               Euro
# XOF  1.0000                EUR               Euro
# XPF  1.0000                EUR               Euro
#
#                                                  rates
# AED  {'currency_name': 'UAE Dirham', 'rate': '4.346...
# AFN  {'currency_name': 'Afghani', 'rate': '91.3730'...
# ALL  {'currency_name': 'Lek', 'rate': '124.1247', '...
# AMD  {'currency_name': 'Armenian Dram', 'rate': '58...
# ANG  {'currency_name': 'Netherlands Antillean Guild...
# ...

# %%
df.to_csv("currencieslist.csv")
df.to_json("currencieslist.json")
# df = df.T
# print(df)
